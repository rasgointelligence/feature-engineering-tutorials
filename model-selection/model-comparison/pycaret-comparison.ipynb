# %% [markdown]
# # Model Type Selection with PyCaret

# %% [markdown]
# This notebook explains how to use `PyCaret` to build multiple models and compare them to pick the best model for your data.
#
# This notebook will build and evaluate a model to predict arrival delay for flights in and out of NYC in 2013.

# %% [markdown]
# ### Packages

# %% [markdown]
# This tutorial uses:
# * [pandas](https://pandas.pydata.org/docs/)
# * [statsmodels](https://www.statsmodels.org/stable/index.html)
#     * [statsmodels.api](https://www.statsmodels.org/stable/api.html#statsmodels-api)
# * [pycaret](https://pycaret.readthedocs.io/en/latest/index.html)
#     * [pycaret.regression](https://pycaret.readthedocs.io/en/latest/api/regression.html)
#     * [pycaret.utils](https://pycaret.readthedocs.io/en/latest/index.html)

# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import pycaret.regression as pycr
import pycaret.utils as pycu

# %% [markdown]
# ## Reading the data

# %% [markdown]
# The data is from `rdatasets` imported using the Python package `statsmodels`.

# %%
df = sm.datasets.get_rdataset('flights', 'nycflights13').data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            336776 non-null  int64
#  1   month           336776 non-null  int64
#  2   day             336776 non-null  int64
#  3   dep_time        328521 non-null  float64
#  4   sched_dep_time  336776 non-null  int64
#  5   dep_delay       328521 non-null  float64
#  6   arr_time        328063 non-null  float64
#  7   sched_arr_time  336776 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         336776 non-null  object
#  10  flight          336776 non-null  int64
#  11  tailnum         334264 non-null  object
#  12  origin          336776 non-null  object
#  13  dest            336776 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        336776 non-null  int64
#  16  hour            336776 non-null  int64
#  17  minute          336776 non-null  int64
#  18  time_hour       336776 non-null  object
# dtypes: float64(5), int64(9), object(5)
# memory usage: 48.8+ MB

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Handle null values

# %%
df.isnull().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %% [markdown]
# As this model will predict arrival delay, the `Null` values are caused by flights did were cancelled or diverted. These can be excluded from this analysis.

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Convert the times from floats or ints to hour and minutes

# %%
df['arr_hour'] = df.arr_time.apply(lambda x: int(np.floor(x/100)))
df['arr_minute'] = df.arr_time.apply(lambda x: int(x - np.floor(x/100)*100))
df['sched_arr_hour'] = df.sched_arr_time.apply(lambda x: int(np.floor(x/100)))
df['sched_arr_minute'] = df.sched_arr_time.apply(lambda x: int(x - np.floor(x/100)*100))
df['sched_dep_hour'] = df.sched_dep_time.apply(lambda x: int(np.floor(x/100)))
df['sched_dep_minute'] = df.sched_dep_time.apply(lambda x: int(x - np.floor(x/100)*100))
df.rename(columns={'hour': 'dep_hour',
                   'minute': 'dep_minute'}, inplace=True)

# %% [markdown]
# As `PyCaret` can use large amounts of memory, we will randomly select **100,000** rows for this comparison, reserving the remaining rows as a test set.

# %%
dftrain = df.sample(n=100000, random_state=1066)
dftest = df.drop(dftrain.index)

# %% [markdown]
# ## Fit the models

# %% [markdown]
# Setup the `PyCaret` environment.  **session_id** is equivalent to **random_state** in `scikit-learn` and allows the experiment to be repeated.

# %%
pycaret_experiment = pycr.setup(data=dftrain, target="arr_delay", session_id=1066,
                                ignore_features=['flight', 'tailnum', 'time_hour', 'year', 'dep_time', 'sched_dep_time', 'arr_time', 'sched_arr_time', 'dep_delay'])
# Out:
# <style  type="text/css" >
# </style><table id="T_6460c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6460c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6460c_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_6460c_row0_col1" class="data row0 col1" >1066</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6460c_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_6460c_row1_col1" class="data row1 col1" >arr_delay</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6460c_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_6460c_row2_col1" class="data row2 col1" >(100000, 25)</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6460c_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_6460c_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6460c_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_6460c_row4_col1" class="data row4 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6460c_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_6460c_row5_col1" class="data row5 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6460c_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_6460c_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6460c_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_6460c_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6460c_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_6460c_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6460c_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_6460c_row9_col1" class="data row9 col1" >(69999, 162)</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_6460c_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_6460c_row10_col1" class="data row10 col1" >(30001, 162)</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_6460c_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_6460c_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_6460c_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_6460c_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_6460c_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_6460c_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_6460c_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_6460c_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_6460c_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_6460c_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_6460c_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_6460c_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_6460c_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_6460c_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_6460c_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_6460c_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_6460c_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_6460c_row19_col1" class="data row19 col1" >c72b</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_6460c_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_6460c_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_6460c_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_6460c_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_6460c_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_6460c_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_6460c_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_6460c_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_6460c_level0_row24" class="row_heading level0 row24" >24</th>
#                         <td id="T_6460c_row24_col0"

# %% [markdown]
# Calling `compare_models` will train about 20 models and show their **MAE**, **MSE**, **RMSE**, **R^2**, **RMSLE**, and **MAPE**.  It will also highlight the best peforming model on each of those metrics.

# %%
best = pycr.compare_models(sort='RMSE')
# Out:
# <style  type="text/css" >
#     #T_1460d_ th {
#           text-align: left;
#     }#T_1460d_row0_col0,#T_1460d_row0_col1,#T_1460d_row0_col5,#T_1460d_row0_col6,#T_1460d_row1_col0,#T_1460d_row1_col2,#T_1460d_row1_col3,#T_1460d_row1_col4,#T_1460d_row2_col0,#T_1460d_row2_col1,#T_1460d_row2_col2,#T_1460d_row2_col3,#T_1460d_row2_col4,#T_1460d_row2_col5,#T_1460d_row2_col6,#T_1460d_row3_col0,#T_1460d_row3_col1,#T_1460d_row3_col2,#T_1460d_row3_col3,#T_1460d_row3_col4,#T_1460d_row3_col5,#T_1460d_row3_col6,#T_1460d_row4_col0,#T_1460d_row4_col1,#T_1460d_row4_col2,#T_1460d_row4_col3,#T_1460d_row4_col4,#T_1460d_row4_col5,#T_1460d_row4_col6,#T_1460d_row5_col0,#T_1460d_row5_col1,#T_1460d_row5_col2,#T_1460d_row5_col3,#T_1460d_row5_col4,#T_1460d_row5_col5,#T_1460d_row5_col6,#T_1460d_row6_col0,#T_1460d_row6_col1,#T_1460d_row6_col2,#T_1460d_row6_col3,#T_1460d_row6_col4,#T_1460d_row6_col5,#T_1460d_row6_col6,#T_1460d_row7_col0,#T_1460d_row7_col1,#T_1460d_row7_col2,#T_1460d_row7_col3,#T_1460d_row7_col4,#T_1460d_row7_col5,#T_1460d_row7_col6,#T_1460d_row8_col0,#T_1460d_row8_col1,#T_1460d_row8_col2,#T_1460d_row8_col3,#T_1460d_row8_col4,#T_1460d_row8_col5,#T_1460d_row8_col6,#T_1460d_row9_col0,#T_1460d_row9_col1,#T_1460d_row9_col2,#T_1460d_row9_col3,#T_1460d_row9_col4,#T_1460d_row9_col5,#T_1460d_row9_col6,#T_1460d_row10_col0,#T_1460d_row10_col1,#T_1460d_row10_col2,#T_1460d_row10_col3,#T_1460d_row10_col4,#T_1460d_row10_col5,#T_1460d_row10_col6,#T_1460d_row11_col0,#T_1460d_row11_col1,#T_1460d_row11_col2,#T_1460d_row11_col3,#T_1460d_row11_col4,#T_1460d_row11_col5,#T_1460d_row11_col6,#T_1460d_row12_col0,#T_1460d_row12_col1,#T_1460d_row12_col2,#T_1460d_row12_col3,#T_1460d_row12_col4,#T_1460d_row12_col5,#T_1460d_row12_col6,#T_1460d_row13_col0,#T_1460d_row13_col1,#T_1460d_row13_col2,#T_1460d_row13_col3,#T_1460d_row13_col4,#T_1460d_row13_col5,#T_1460d_row13_col6,#T_1460d_row14_col0,#T_1460d_row14_col1,#T_1460d_row14_col2,#T_1460d_row14_col3,#T_1460d_row14_col4,#T_1460d_row14_col5,#T_1460d_row14_col6,#T_1460d_row15_col0,#T_1460d_row15_col1,#T_1460d_row15_col2,#T_1460d_row15_col3,#T_1460d_row15_col4,#T_1460d_row15_col5,#T_1460d_row15_col6,#T_1460d_row16_col0,#T_1460d_row16_col1,#T_1460d_row16_col2,#T_1460d_row16_col3,#T_1460d_row16_col4,#T_1460d_row16_col5,#T_1460d_row16_col6,#T_1460d_row17_col0,#T_1460d_row17_col1,#T_1460d_row17_col2,#T_1460d_row17_col3,#T_1460d_row17_col4,#T_1460d_row17_col5,#T_1460d_row17_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_1460d_row0_col2,#T_1460d_row0_col3,#T_1460d_row0_col4,#T_1460d_row1_col1,#T_1460d_row1_col5,#T_1460d_row1_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_1460d_row0_col7,#T_1460d_row1_col7,#T_1460d_row2_col7,#T_1460d_row3_col7,#T_1460d_row4_col7,#T_1460d_row5_col7,#T_1460d_row6_col7,#T_1460d_row7_col7,#T_1460d_row9_col7,#T_1460d_row10_col7,#T_1460d_row11_col7,#T_1460d_row12_col7,#T_1460d_row13_col7,#T_1460d_row14_col7,#T_1460d_row15_col7,#T_1460d_row16_col7,#T_1460d_row17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_1460d_row8_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_1460d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1460d_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_1460d_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_1460d_row0_col1" class="data row0 col1" >1.9788</td>
#                         <td id="T_1460d_row0_col2" class="data row0 col2" >36.7907</td>
#                         <td id="T_1460d_row0_col3" class="data row0 col3" >5.5109</td>
#                         <td id="T_1460d_row0_col4" class="data row0 col4" >0.9818</td>
#                         <td id="T_1460d_row0_col5" class="data row0 col5" >0.2145</td>
#                         <td id="T_1460d_row0_col6" class="data row0 col6" >0.1533</td>
#                         <td id="T_1460d_row0_col7" class="data row0 col7" >4.0700</td>
#             </tr>
#             <tr>
#                         <th id="T_1460d_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_1460d_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#                         <td id="T_1460d_row1_col1" class="data row1 col1" >1.0965</td>
#                         <td id="T_1460d_row1_col2" class="data row1 col2" >38.4911</td>
#                         <td id="T_1460d_row1_col3" class="data row1 col3" >5.6290</td>
#                         <td id="T_1460d_row1_col4" class="data row1 col4" >0.9809</td>
#                         <td id="T_1460d_row1_col5" class="data row1 col5" >0.1149</td>
#                         <td id="T_1460d_row1_col6" class="data row1 col6" >0.0655</td>
#                         <td id="T_1460d_row1_col7" class="data row1 col7" >25.0300</td>
#             </tr>
#             <tr>
#                         <th id="T_1460d_level0_row2" class="row_heading level0 row2" >et</th>
#                         <td id="T_1460d_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#                         <td id="T_1460d_row2_col1" class="data row2 col1" >1.3357</td>
#                         <td id="T_1460d_row2_col2" class="data row2 col2" >42.8113</td>
#                         <td id="T_1460d_row2_col3" class="data row2 col3" >6.1431</td>
#                         <td id="T_1460d_row2_col4" class="data row2 col4" >0.9788</td>
#                         <td id="T_1460d_row2_col5" class="data row2 col5" >0.1510</td>
#                         <td id="T_1460d_row2_col6" class="data row2 col6" >0.0817</td>
#                         <td id="T_1460d_row2_col7" class="data row2 col7" >35.5990</td>
#             </tr>
#             <tr>
#                         <th id="T_1460d_level0_row3" class="row_heading level0 row3" >xgboost</th>
#                         <td id="T_1460d_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_1460d_row3_col1" class="data row3 col1" >3.2131</td>
#                         <td id="T_1460d_row3_col2" class="data row3 col2" >40.0363</td>
#                         <td id="T_1460d_row3_col3" class="data row3 col3" >6.1862</td>
#                         <td id="T_1460d_row3_col4" class="data row3 col4" >0.9800</td>
#                         <td id="T_1460d_row3_col5" class="data row3 col5" >0.3423</td>
#                         <td id="T_1460d_row3_col6" class="data row3 col6" >0.2805</td>
#                         <td id="T_1460d_row3_col7" class="data row3 col7" >17.1310</td>
#             </tr>
#             <tr>
#                         <th id="T_1460d_level0_row4" class="row_heading level0 row4" >dt</th>
#                         <td id="T_1460d_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#                         <td id="T_1460d_row4_col1" class="data row4 col1" >1.7987</td>
#                         <td id="T_1460d_row4_col2" class="data row4 col2" >54.8896</td>
#                         <td id="T_1460d_row4_col3" class="data row4 col3" >6.8635</td>
#                         <td id="T_1460d_row4_col4" class="data row4 col4" >0.9728</td>
#                         <td id="T_1460d_row4_col5" class="data row4 col5" >0.2031</td>
#                         <td id="T_1460d_row4_col6" class="data row4 col6" >0.1283</td>

# %% [markdown]
# Calling `create_model` with one of the types above, will create the model that can then be used like any other model.

# %%
catboost = pycr.create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_34d9b_row10_col0,#T_34d9b_row10_col1,#T_34d9b_row10_col2,#T_34d9b_row10_col3,#T_34d9b_row10_col4,#T_34d9b_row10_col5{
#             background:  yellow;
#         }</style><table id="T_34d9b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34d9b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_34d9b_row0_col0" class="data row0 col0" >2.0394</td>
#                         <td id="T_34d9b_row0_col1" class="data row0 col1" >95.0439</td>
#                         <td id="T_34d9b_row0_col2" class="data row0 col2" >9.7490</td>
#                         <td id="T_34d9b_row0_col3" class="data row0 col3" >0.9536</td>
#                         <td id="T_34d9b_row0_col4" class="data row0 col4" >0.2097</td>
#                         <td id="T_34d9b_row0_col5" class="data row0 col5" >0.1461</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_34d9b_row1_col0" class="data row1 col0" >1.9653</td>
#                         <td id="T_34d9b_row1_col1" class="data row1 col1" >13.1927</td>
#                         <td id="T_34d9b_row1_col2" class="data row1 col2" >3.6322</td>
#                         <td id="T_34d9b_row1_col3" class="data row1 col3" >0.9936</td>
#                         <td id="T_34d9b_row1_col4" class="data row1 col4" >0.2171</td>
#                         <td id="T_34d9b_row1_col5" class="data row1 col5" >0.1557</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_34d9b_row2_col0" class="data row2 col0" >2.0037</td>
#                         <td id="T_34d9b_row2_col1" class="data row2 col1" >12.6137</td>
#                         <td id="T_34d9b_row2_col2" class="data row2 col2" >3.5516</td>
#                         <td id="T_34d9b_row2_col3" class="data row2 col3" >0.9933</td>
#                         <td id="T_34d9b_row2_col4" class="data row2 col4" >0.2239</td>
#                         <td id="T_34d9b_row2_col5" class="data row2 col5" >0.1662</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_34d9b_row3_col0" class="data row3 col0" >2.0038</td>
#                         <td id="T_34d9b_row3_col1" class="data row3 col1" >17.1477</td>
#                         <td id="T_34d9b_row3_col2" class="data row3 col2" >4.1410</td>
#                         <td id="T_34d9b_row3_col3" class="data row3 col3" >0.9914</td>
#                         <td id="T_34d9b_row3_col4" class="data row3 col4" >0.2165</td>
#                         <td id="T_34d9b_row3_col5" class="data row3 col5" >0.1585</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_34d9b_row4_col0" class="data row4 col0" >1.8106</td>
#                         <td id="T_34d9b_row4_col1" class="data row4 col1" >9.8252</td>
#                         <td id="T_34d9b_row4_col2" class="data row4 col2" >3.1345</td>
#                         <td id="T_34d9b_row4_col3" class="data row4 col3" >0.9948</td>
#                         <td id="T_34d9b_row4_col4" class="data row4 col4" >0.2090</td>
#                         <td id="T_34d9b_row4_col5" class="data row4 col5" >0.1422</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_34d9b_row5_col0" class="data row5 col0" >1.9573</td>
#                         <td id="T_34d9b_row5_col1" class="data row5 col1" >37.8786</td>
#                         <td id="T_34d9b_row5_col2" class="data row5 col2" >6.1546</td>
#                         <td id="T_34d9b_row5_col3" class="data row5 col3" >0.9814</td>
#                         <td id="T_34d9b_row5_col4" class="data row5 col4" >0.2032</td>
#                         <td id="T_34d9b_row5_col5" class="data row5 col5" >0.1530</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_34d9b_row6_col0" class="data row6 col0" >2.0721</td>
#                         <td id="T_34d9b_row6_col1" class="data row6 col1" >93.5713</td>
#                         <td id="T_34d9b_row6_col2" class="data row6 col2" >9.6732</td>
#                         <td id="T_34d9b_row6_col3" class="data row6 col3" >0.9533</td>
#                         <td id="T_34d9b_row6_col4" class="data row6 col4" >0.2080</td>
#                         <td id="T_34d9b_row6_col5" class="data row6 col5" >0.1536</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_34d9b_row7_col0" class="data row7 col0" >1.9391</td>
#                         <td id="T_34d9b_row7_col1" class="data row7 col1" >15.2617</td>
#                         <td id="T_34d9b_row7_col2" class="data row7 col2" >3.9066</td>
#                         <td id="T_34d9b_row7_col3" class="data row7 col3" >0.9926</td>
#                         <td id="T_34d9b_row7_col4" class="data row7 col4" >0.2142</td>
#                         <td id="T_34d9b_row7_col5" class="data row7 col5" >0.1474</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_34d9b_row8_col0" class="data row8 col0" >2.0233</td>
#                         <td id="T_34d9b_row8_col1" class="data row8 col1" >62.9052</td>
#                         <td id="T_34d9b_row8_col2" class="data row8 col2" >7.9313</td>
#                         <td id="T_34d9b_row8_col3" class="data row8 col3" >0.9699</td>
#                         <td id="T_34d9b_row8_col4" class="data row8 col4" >0.2108</td>
#                         <td id="T_34d9b_row8_col5" class="data row8 col5" >0.1473</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_34d9b_row9_col0" class="data row9 col0" >1.9735</td>
#                         <td id="T_34d9b_row9_col1" class="data row9 col1" >10.4671</td>
#                         <td id="T_34d9b_row9_col2" class="data row9 col2" >3.2353</td>
#                         <td id="T_34d9b_row9_col3" class="data row9 col3" >0.9942</td>
#                         <td id="T_34d9b_row9_col4" class="data row9 col4" >0.2328</td>
#                         <td id="T_34d9b_row9_col5" class="data row9 col5" >0.1628</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_34d9b_row10_col0" class="data row10 col0" >1.9788</td>
#                         <td id="T_34d9b_row10_col1" class="data row10 col1" >36.7907</td>
#                         <td id="T_34d9b_row10_col2" class="data row10 col2" >5.5109</td>
#                         <td id="T_34d9b_row10_col3" class="data row10 col3" >0.9818</td>
#                         <td id="T_34d9b_row10_col4" class="data row10 col4" >0.2145</td>
#                         <td id="T_34d9b_row10_col5" class="data row10 col5" >0.1533</td>
#             </tr>
#             <tr>
#                         <th id="T_34d9b_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_34d9b_row11_col0" class="data row11 col0" >0.0679</td

# %% [markdown]
# Evaluate this model on the hold_out sample

# %%
predict_result = pycr.predict_model(catboost)
# Out:
# <style  type="text/css" >
# </style><table id="T_fff23_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fff23_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fff23_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_fff23_row0_col1" class="data row0 col1" >1.9158</td>
#                         <td id="T_fff23_row0_col2" class="data row0 col2" >30.7283</td>
#                         <td id="T_fff23_row0_col3" class="data row0 col3" >5.5433</td>
#                         <td id="T_fff23_row0_col4" class="data row0 col4" >0.9849</td>
#                         <td id="T_fff23_row0_col5" class="data row0 col5" >0.2069</td>
#                         <td id="T_fff23_row0_col6" class="data row0 col6" >0.1498</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# This model is built using the default hyperparameters.  The model with tuned hyperparameters can be found using `tune_model`.

# %%
catboost = pycr.tune_model(catboost)
# Out:
# <style  type="text/css" >
# #T_2aecd_row10_col0,#T_2aecd_row10_col1,#T_2aecd_row10_col2,#T_2aecd_row10_col3,#T_2aecd_row10_col4,#T_2aecd_row10_col5{
#             background:  yellow;
#         }</style><table id="T_2aecd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2aecd_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2aecd_row0_col0" class="data row0 col0" >2.3507</td>
#                         <td id="T_2aecd_row0_col1" class="data row0 col1" >116.4995</td>
#                         <td id="T_2aecd_row0_col2" class="data row0 col2" >10.7935</td>
#                         <td id="T_2aecd_row0_col3" class="data row0 col3" >0.9431</td>
#                         <td id="T_2aecd_row0_col4" class="data row0 col4" >0.2424</td>
#                         <td id="T_2aecd_row0_col5" class="data row0 col5" >0.1784</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2aecd_row1_col0" class="data row1 col0" >2.5108</td>
#                         <td id="T_2aecd_row1_col1" class="data row1 col1" >22.7701</td>
#                         <td id="T_2aecd_row1_col2" class="data row1 col2" >4.7718</td>
#                         <td id="T_2aecd_row1_col3" class="data row1 col3" >0.9890</td>
#                         <td id="T_2aecd_row1_col4" class="data row1 col4" >0.2792</td>
#                         <td id="T_2aecd_row1_col5" class="data row1 col5" >0.2172</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2aecd_row2_col0" class="data row2 col0" >2.2563</td>
#                         <td id="T_2aecd_row2_col1" class="data row2 col1" >26.8256</td>
#                         <td id="T_2aecd_row2_col2" class="data row2 col2" >5.1793</td>
#                         <td id="T_2aecd_row2_col3" class="data row2 col3" >0.9858</td>
#                         <td id="T_2aecd_row2_col4" class="data row2 col4" >0.2707</td>
#                         <td id="T_2aecd_row2_col5" class="data row2 col5" >0.1974</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2aecd_row3_col0" class="data row3 col0" >2.4275</td>
#                         <td id="T_2aecd_row3_col1" class="data row3 col1" >47.8128</td>
#                         <td id="T_2aecd_row3_col2" class="data row3 col2" >6.9147</td>
#                         <td id="T_2aecd_row3_col3" class="data row3 col3" >0.9761</td>
#                         <td id="T_2aecd_row3_col4" class="data row3 col4" >0.2687</td>
#                         <td id="T_2aecd_row3_col5" class="data row3 col5" >0.2114</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2aecd_row4_col0" class="data row4 col0" >2.2783</td>
#                         <td id="T_2aecd_row4_col1" class="data row4 col1" >13.9257</td>
#                         <td id="T_2aecd_row4_col2" class="data row4 col2" >3.7317</td>
#                         <td id="T_2aecd_row4_col3" class="data row4 col3" >0.9927</td>
#                         <td id="T_2aecd_row4_col4" class="data row4 col4" >0.2747</td>
#                         <td id="T_2aecd_row4_col5" class="data row4 col5" >0.2036</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2aecd_row5_col0" class="data row5 col0" >2.3571</td>
#                         <td id="T_2aecd_row5_col1" class="data row5 col1" >50.3552</td>
#                         <td id="T_2aecd_row5_col2" class="data row5 col2" >7.0961</td>
#                         <td id="T_2aecd_row5_col3" class="data row5 col3" >0.9752</td>
#                         <td id="T_2aecd_row5_col4" class="data row5 col4" >0.2491</td>
#                         <td id="T_2aecd_row5_col5" class="data row5 col5" >0.1948</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2aecd_row6_col0" class="data row6 col0" >2.5718</td>
#                         <td id="T_2aecd_row6_col1" class="data row6 col1" >173.7631</td>
#                         <td id="T_2aecd_row6_col2" class="data row6 col2" >13.1819</td>
#                         <td id="T_2aecd_row6_col3" class="data row6 col3" >0.9133</td>
#                         <td id="T_2aecd_row6_col4" class="data row6 col4" >0.2706</td>
#                         <td id="T_2aecd_row6_col5" class="data row6 col5" >0.2126</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2aecd_row7_col0" class="data row7 col0" >2.4011</td>
#                         <td id="T_2aecd_row7_col1" class="data row7 col1" >53.7416</td>
#                         <td id="T_2aecd_row7_col2" class="data row7 col2" >7.3309</td>
#                         <td id="T_2aecd_row7_col3" class="data row7 col3" >0.9740</td>
#                         <td id="T_2aecd_row7_col4" class="data row7 col4" >0.2814</td>
#                         <td id="T_2aecd_row7_col5" class="data row7 col5" >0.2061</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2aecd_row8_col0" class="data row8 col0" >2.6607</td>
#                         <td id="T_2aecd_row8_col1" class="data row8 col1" >53.3262</td>
#                         <td id="T_2aecd_row8_col2" class="data row8 col2" >7.3025</td>
#                         <td id="T_2aecd_row8_col3" class="data row8 col3" >0.9744</td>
#                         <td id="T_2aecd_row8_col4" class="data row8 col4" >0.2780</td>
#                         <td id="T_2aecd_row8_col5" class="data row8 col5" >0.2101</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2aecd_row9_col0" class="data row9 col0" >2.2036</td>
#                         <td id="T_2aecd_row9_col1" class="data row9 col1" >14.4401</td>
#                         <td id="T_2aecd_row9_col2" class="data row9 col2" >3.8000</td>
#                         <td id="T_2aecd_row9_col3" class="data row9 col3" >0.9920</td>
#                         <td id="T_2aecd_row9_col4" class="data row9 col4" >0.2585</td>
#                         <td id="T_2aecd_row9_col5" class="data row9 col5" >0.1939</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_2aecd_row10_col0" class="data row10 col0" >2.4018</td>
#                         <td id="T_2aecd_row10_col1" class="data row10 col1" >57.3460</td>
#                         <td id="T_2aecd_row10_col2" class="data row10 col2" >7.0102</td>
#                         <td id="T_2aecd_row10_col3" class="data row10 col3" >0.9716</td>
#                         <td id="T_2aecd_row10_col4" class="data row10 col4" >0.2673</td>
#                         <td id="T_2aecd_row10_col5" class="data row10 col5" >0.2025</td>
#             </tr>
#             <tr>
#                         <th id="T_2aecd_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_2aecd_row11_col0" class="data row11 col0" >0.137

# %% [markdown]
# Evaluate this model on the hold_out sample

# %%
tuned_result = pycr.predict_model(catboost)
# Out:
# <style  type="text/css" >
# </style><table id="T_de6bf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de6bf_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_de6bf_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_de6bf_row0_col1" class="data row0 col1" >2.3154</td>
#                         <td id="T_de6bf_row0_col2" class="data row0 col2" >48.6610</td>
#                         <td id="T_de6bf_row0_col3" class="data row0 col3" >6.9757</td>
#                         <td id="T_de6bf_row0_col4" class="data row0 col4" >0.9761</td>
#                         <td id="T_de6bf_row0_col5" class="data row0 col5" >0.2608</td>
#                         <td id="T_de6bf_row0_col6" class="data row0 col6" >0.1978</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Finalize the model for deployment by fitting the model onto all of the data including the hold-out.

# %%
final_catboost = pycr.finalize_model(catboost)

# %% [markdown]
# Use this final model to predict on the observations not sampled above

# %%
predictions = pycr.predict_model(final_catboost, data=dftest)

# %% [markdown]
# Check the **R^2** for these predictions

# %%
pycu.check_metric(predictions.arr_delay, predictions.Label, 'R2')
# Out:
# 0.9822
