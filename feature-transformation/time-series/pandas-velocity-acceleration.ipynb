# %% [markdown]
# # Velocity and Acceleration in Pandas Tutorial

# %% [markdown]
# This notebook explains how to create velocity and acceleration features in `pandas`.
#
# This notebook will use gold and silver price data from `rdatasets` for this tutorial

# %% [markdown]
# ### Packages

# %% [markdown]
# The documentation for each package used in this tutorial is linked below:
# * [pandas](https://pandas.pydata.org/docs/)
# * [statsmodels](https://www.statsmodels.org/stable/index.html)
#     * [statsmodels.api](https://www.statsmodels.org/stable/api.html#statsmodels-api)

# %%
import statsmodels.api as sm
import pandas as pd

# %% [markdown]
# ## Create initial dataset

# %% [markdown]
# The data is from `rdatasets` imported using the Python package `statsmodels`.

# %%
df = sm.datasets.get_rdataset('GoldSilver', 'AER').data.reset_index().rename(columns={'index': 'date'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9132 entries, 0 to 9131
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    9132 non-null   object
#  1   gold    9132 non-null   float64
#  2   silver  9132 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 214.2+ KB

# %%
df['date'] = pd.to_datetime(df.date)

# %% [markdown]
# ## Time series aggregation

# %% [markdown]
# The `pandas` function `resample` can be used to create aggregations on specified windows.  Here, a weekly aggregate of the daily gold and silver price data will be created.
#
# First, a datetime index needs to be created from the **date** column.

# %%
df.set_index('date', inplace=True)

# %% [markdown]
# The parameter **origin** is used to specify the day of week to start the aggregation on.  January 1, 1978 is a Sunday, so each of these aggreagtions will start on Sunday and aggregate over the subsequent week.

# %%
weekly_resample = df.resample('7D', origin=pd.to_datetime('1978-01-01'))
aggregated_df = weekly_resample.agg(['min', 'mean', 'max', 'std'])
aggregated_df.columns = ['_'.join(col).strip() + '_week' for col in aggregated_df.columns.values]

# %% [markdown]
# ### Velocity

# %% [markdown]
# Calculate the velocity of the mean weekly gold price as the difference between means divided by the number of days between.

# %%
aggregated_df['gold_velocity_1wk'] = (aggregated_df['gold_mean_week'] - aggregated_df['gold_mean_week'].shift(1))/7
aggregated_df['gold_velocity_4wk'] = (aggregated_df['gold_mean_week'] - aggregated_df['gold_mean_week'].shift(4))/28
aggregated_df.head(20)
# Out:
#             gold_min_week  gold_mean_week  gold_max_week  gold_std_week  \
# date
# 1977-12-25         100.00         100.000         100.00            NaN
# 1978-01-01         100.00         100.000         100.00       0.000000
# 1978-01-08         100.88         101.586         102.62       0.796825
# 1978-01-15         100.87         101.832         103.09       0.796976
# 1978-01-22         102.49         103.306         103.62       0.475742
# 1978-01-29         101.96         102.578         103.49       0.636530
# 1978-02-05         101.90         102.572         103.15       0.505193
# 1978-02-12         103.92         104.936         105.87       0.850312
# 1978-02-19         105.14         105.956         107.23       0.822028
# 1978-02-26         106.20         107.076         107.60       0.538451
# 1978-03-05         108.89         109.916         111.03       0.791789
# 1978-03-12         106.05         108.042         110.39       1.638740
# 1978-03-19         102.65         104.458         105.53       1.355865
# 1978-03-26         104.66         106.180         107.29       1.119710
# 1978-04-02         103.33         103.968         105.27       0.771894
# 1978-04-09         102.99         104.120         105.07       0.806908
# 1978-04-16          99.11          99.996         100.93       0.852397
# 1978-04-23          97.45          98.234          99.41       0.856756
# 1978-04-30          98.38          99.778         100.92       1.143119
# 1978-05-07         100.11         100.874         101.51       0.644306
#
#             silver_min_week  silver_mean_week  silver_max_week  \
# date
# 1977-12-25           223.42           223.420           223.42
# 1978-01-01           223.42           226.604           229.84
# 1978-01-08           227.89           230.050           232.55
# 1978-01-15           227.96           229.686           232.49
# 1978-01-22           230.37           232.798           234.50
# 1978-01-29           226.91           229.116           231.61
# 1978-02-05           224.98           227.506           229.90
# 1978-02-12           228.16           231.506           234.01
# 1978-02-19           229.81           232.392           234.55
# 1978-02-26           229.83           231.092           232.22
# 1978-03-05           235.33           244.862           248.98
# 1978-03-12           248.09           251.940           254.95
# 1978-03-19           240.71           243.672           246.05
# 1978-03-26           246.81           249.628           253.55
# 1978-04-02           241.89           243.780           246.38
# 1978-04-09           241.23           243.816           247.27
# 1978-04-16           230.53           232.784           235.15
# 1978-04-23           225.99           228.588           230.49
# 1978-04-30           228.87           232.358           234.71
# 1978-05-07           232.08           233.124           234.55
#
#             silver_std_week  gold_velocity  gold_velocity_1wk  \
# date
# 1977-12-25              NaN            NaN                NaN
# 1978-01-01         2.596657       0.000000           0.000000
# 1978-01-08         1.846334       0.226571           0.226571
# 1978-01-15         1.755130       0.035143           0.035143
# 1978-01-22         1.777630       0.210571           0.210571
# 1978-01-29         1.936835      -0.104000          -0.104000
# 1978-02-05         1.875361      -0.000857          -0.000857
# 1978-02-12         2.412370       0.337714           0.337714
# 1978-02-19         1.784550       0.145714           0.145714
# 1978-02-26         1.043681       0.160000           0.160000
# 1978-03-05         5.619695       0.405714           0.405714
# 1978-03-12         2.875239      -0.267714          -0.267714
# 1978-03-19         2.578317      -0.512000          -0.512000
# 1978-03-26         2.764710       0.246000           0.246000
# 1978-04-02         1.809627      -0.316000          -0.316000
# 1978-04-09         2.410940       0.021714           0.021714
# 1978-04-16         2.045527      -0.589143          -0.589143
# 1978-04-23         1.848194      -0.251714          -0.251714
# 1978-04-30         2.439912       0.220571           0.220571
# 1978-05-07         0.905003       0.156571           0.156571
#
#             gold_velocity_4wk
# date
# 1977-12-25                NaN
# 1978-01-01                NaN
# 1978-01-08                NaN
# 1978-01-15                NaN
# 1978-01-22           0.118071
# 1978-01-29           0.092071
# 1978-02-05           0.035214
# 1978-02-12           0.110857
# 1978-02-19           0.094643
# 1978-02-26           0.160643
# 1978-03-05           0.262286
# 1978-03-12           0.110929
# 1978-03-19          -0.053500
# 1978-03-26          -0.032000
# 1978-04-02          -0.212429
# 1978-04-09          -0.140071
# 1978-04-16          -0.159357
# 1978-04-23          -0.283786
# 1978-04-30          -0.149643
# 1978-05-07          -0.115929

# %% [markdown]
# ### Accelerations

# %% [markdown]
# Calculate the accelerations of the mean weekly gold price as the difference between velocities divided by the number of days between.

# %%
aggregated_df['gold_acceleration_1wk'] = (aggregated_df['gold_velocity_1wk'] - aggregated_df['gold_velocity_1wk'].shift(1))/7
aggregated_df['gold_acceleration_4wk'] = (aggregated_df['gold_velocity_4wk'] - aggregated_df['gold_velocity_4wk'].shift(4))/28
aggregated_df.head(20)
# Out:
#             gold_min_week  gold_mean_week  gold_max_week  gold_std_week  \
# date
# 1977-12-25         100.00         100.000         100.00            NaN
# 1978-01-01         100.00         100.000         100.00       0.000000
# 1978-01-08         100.88         101.586         102.62       0.796825
# 1978-01-15         100.87         101.832         103.09       0.796976
# 1978-01-22         102.49         103.306         103.62       0.475742
# 1978-01-29         101.96         102.578         103.49       0.636530
# 1978-02-05         101.90         102.572         103.15       0.505193
# 1978-02-12         103.92         104.936         105.87       0.850312
# 1978-02-19         105.14         105.956         107.23       0.822028
# 1978-02-26         106.20         107.076         107.60       0.538451
# 1978-03-05         108.89         109.916         111.03       0.791789
# 1978-03-12         106.05         108.042         110.39       1.638740
# 1978-03-19         102.65         104.458         105.53       1.355865
